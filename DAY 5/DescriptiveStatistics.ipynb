# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
np.random.seed(42)
data = {
    "Math_Score": np.random.randint(40, 100, 30),
    "Science_Score": np.random.randint(35, 95, 30)
}
df =- pd.DataFrame(data)

print("Dataset:\n", df)

# %%
desc_stats = df.describe()
print("\nDescriptive Statistics:\n", desc_stats)

# %%
central_tendency = {
    "Mean": df.mean(),
    "Median": df.median(),
    "Mode": df.mode().iloc[0]
}
print("\nCentral Tendency Measures:\n", pd.DataFrame(central_tendency))

# %%
dispersion = {
    "Variance": df.var(),
    "Standard Deviation": df.std(),
    "Range": df.max() - df.min(),
    "Interquartile Range (IQR)": desc_stats.loc['75%'] - desc_stats.loc['25%']
}
print("\nDispersion Measures:\n", pd.DataFrame(dispersion))

# %%
dispersion = {
    "Variance": df.var(),
    "Standard Deviation": df.std(),
    "Range": df.max() - df.min(),
    "IQR": df.quantile(0.75) - df.quantile(0.25)
}
print("\nDispersion Measures:\n", pd.DataFrame(dispersion))

# %%
plt.figure(figsize=(10, 5))
sns.histplot(df["Math_Score"], bins=6, kde=True, color='skyblue', edgecolor='black')
plt.title("Muslim Siva Sanjay Tipper Tanu Haripriya Payaluga")
plt.xlabel("Score Range")
plt.ylabel("Frequency")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(5, 5))
sns.boxplot(x=df["Science_Score"], color='maroon')
plt.title("Box Plot of Science Scores")
plt.xlabel("Score")
plt.grid(True)
plt.tight_layout()
plt.show()
