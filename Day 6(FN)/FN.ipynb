# %%
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# Example model creation
model = LogisticRegression(max_iter=1000)

# %%
import pandas as pd

# Load the CSV file
df = pd.read_csv(r"C:\Users\ajays\OneDrive\Desktop\Data-Scientist\Day 6(FN)\insurance_data.csv")

# Display first 5 rows
print(df.head())

# Display dataset information
print("\nDataset Info:")
df.info()
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1
#
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   age               27 non-null     int64
#  1   bought_insurance  27 non-null     int64
# dtypes: int64(2)
# memory usage: 560.0 bytes

# %%
plt.scatter(df['age'], df['bought_insurance'], color="#ff0077", marker='x')
plt.xlabel('Age')
plt.ylabel('Bought Insurance (0 = No, 1 = Yes)')
plt.title('Age vs Bought Insurance')
plt.grid(True)
plt.show()

# %%
x = df[['age']]
y = df['bought_insurance']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.1, random_state=2)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (24, 1)
# (3, 1)
# (24,)
# (3,)

# %%
model = LogisticRegression()
model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(x_test)

print("Predicted values:", y_pred.tolist)
print("Actual values:", y_test.tolist())
# Out:
# Predicted values: <built-in method tolist of numpy.ndarray object at 0x000001D368ABB6F0>
# Actual values: [1, 0, 1]

# %%
actual = actual_values(y_test, y_pred)
print("Accuracy:" , actual)

cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:\n", cm)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 actual = actual_values(y_test, y_pred)
#       2 print("Accuracy:" , actual)
#       4 cm = confusion_matrix(y_test, y_pred)
#
# NameError: name 'actual_values' is not defined

# %%
# Import required libraries
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression

# Training data (age vs result)
X = np.array([[20], [30], [40], [50], [60], [70]])
y = np.array([0, 0, 0, 1, 1, 1])

# Create and train the model
model = LogisticRegression()
model.fit(X, y)

# Generate age values for prediction
ages = np.linspace(20, 80, 100).reshape(-1, 1)

# Predict probabilities
probs = model.predict_proba(ages)[:, 1]

# Plot the result
plt.plot(ages, probs)
plt.xlabel("Age")
plt.ylabel("Probability")
plt.title("Logistic Regression Curve")
plt.show()

# %%
print("Will a 40-year-old buy insurance?")
print("Prediction (0=No, 1=Yes):", model.predict([[40]]))
print("Probability:", model.predict_proba([[40]])[0][1])
# Out:
# Will a 40-year-old buy insurance?
# Prediction (0=No, 1=Yes): [0]
# Probability: 0.05590556294228887

# %%
a = model.predict_proba([[40]])
print(a.shape)
print(a)
# Out:
# (1, 2)
# [[0.94409444 0.05590556]]

# %%
x_test_sorted = x_test.sort_values(by='age')
y_test_sorted = y_test[x_test_sorted.index]
y_pred_sorted = model.predict(x_test_sorted)

plt.figure(figsize=(10, 6))
plt.scatter(x_test_sorted, y_test_sorted, color='blue', label='Actual', marker='o')
plt.plot(x_test_sorted['age'], y_pred_sorted, color='red', label='Predicted', linewidth=2)
plt.xlabel('Age')
plt.ylabel('Bought Insurance (0 = No, 1 = Yes)')
plt.title('Logistic Regression: Actual vs Predicted')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 x_test_sorted = x_test.sort_values(by='age')
#       2 y_test_sorted = y_test[x_test_sorted.index]
#       3 y_pred_sorted = model.predict(x_test_sorted)
#
# NameError: name 'x_test' is not defined
